# %%
def entrada():
    # Essas entradas recebem as listas 1 e 2
    entrada1,entrada2 = [],[]
    # modo_adc - configura o modo de adição dos dados às listas
    modo_adc = input("Gostaria de adicionar os termos independentes (A)leatoriamente ou (M)anualmente?")
    tam = int(input("Insira o tamanho das listas:"))
    
    # Conferindo os dados inseridos
    while (modo_adc != 'M') and (modo_adc != 'A') and (modo_adc != 'm') and (modo_adc != 'a'):
        modo_adc = input("Gostaria de adicionar os termos independentes (A)leatoriamente ou (M)anualmente?")
    while tam <= 0:
         tam = int(input("Insira o tamanho das listas:"))
     
    if (modo_adc == 'a') or (modo_adc == 'A'):
        A1 = range(tam)
        for item in A1:
            entrada1.append(int(item*(item+1)/2))
        A2 = range(tam)
        for item in A2:
            entrada2.append(item)

    elif(modo_adc == 'm') or (modo_adc == 'M'):
            print ('Insira os algarismo de 1 em 1, entre 0 e 9, da esquerda pra direita (atenção! escreva um número por linha - pressione entre após inserir cada número)\n')
            cont = 0
            for numero in range(tam):
                while cont < tam:
                    alg =input()
                    alg = int(alg)
                    cont += 1
                    auxiliar = []
                    auxiliar.append(alg)
                    for item in auxiliar:
                        entrada1.append(int(item*(item+1)/2))
                    for item in auxiliar:
                        entrada2.append(item)
    A = entrada1
    B = entrada2
    return (A,B)
# Entrada = finalizado

#Função que encontra o valor de X
def sistema_triangular(A,B):
    # X = A/B
    X = []
    cont = 0
    while cont < len(A):
        if B[cont] != 0:
            X.append(A[cont]/B[cont])
            cont += 1
        elif B[cont] == 0:
            X.append(0.0)
            cont += 1
    return(A,B,X)
#X = finalizado

def exibe(A,B,X):
    # lista b (soma das multiplicações - lista B)
    b = []
    soma = 0
    for item in B:
        soma += item
        b.append(soma)
    print(b)
    
    cont = 0
    i = 0
    a = ""
    c = ""
    while cont < len(A):
        if i == 0:
            var1 = str(A[i])
            var2 = str(X[i])
            var3 = str(b[i])
            a  += "("+var1+")"+"*"+"("+var2+")"
            c = " = "+var3
            resposta = a+c
            print(resposta)
            cont+=1
            i+=1
        else:
            var1 = str(A[i])
            var2 = str(X[i])
            var3 = str(b[i])
            a  += " + "+"("+var1+")"+"*"+"("+var2+")"
            c = " = "+var3
            resposta = a+c
            print(resposta)
            cont+=1
            i+=1
